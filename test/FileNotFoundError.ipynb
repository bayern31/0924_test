# %%
excel_df = pd.read_excel("iris_excel_240930.xlsx")
excel_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
excel_df = pd.read_excel("Model_Toyo Suisan Kaisha.xlsx")
excel_df
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                     Japan Consumer
# 3          NaN                                                NaN
# 4          NaN                                             2875.T
# 5          NaN                                 Toyo Suisan Kaisha
# 6          NaN                                             Rating
# 7          NaN  Target Price/ Target price period/ Upside/down...
# 8          NaN                M&A probability (1 = high, 3 = low)
# 9          NaN                               Market Cap (JPY mn):
# 10         NaN                   Current shares outstanding (mn):
# 11         NaN                       Price (as of Jan 31, 2024) :
# 12         NaN                                          Currency:
# ...
