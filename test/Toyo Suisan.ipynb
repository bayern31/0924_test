# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %%
df = pd.read_excel("Model_Toyo Suisan Kaisha.xlsx", sheet_name=[1, 2])
df
# Out:
# {1:                      Unnamed: 0     Unnamed: 1 Unnamed: 2 Unnamed: 3  \
#  0   Toyo Suisan Kaisha (2875.T)  東洋水産 (2875.T)        NaN        NaN
#  1                  JPY millions            百万円        NaN        NaN
#  2                           NaN            NaN        NaN        NaN
#  3                           NaN            NaN        NaN        NaN
#  4                           NaN           収益推移        NaN        NaN
#  5                           NaN            NaN        NaN        NaN
#  6                           NaN          (Ymn)        NaN        NaN
#  7                           NaN            NaN     2008年度     2009年度
#  8                           NaN            NaN        NaN        NaN
#  9                           NaN            NaN        NaN        NaN
#  10                          NaN            売上高     322063     315337
#  11                          NaN            YoY        NaN  -0.020884
# ...
